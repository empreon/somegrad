# %%
import sys
sys.path.append('..')
from somegrad import Tensor
import somegrad.functional as F

# %%
import numpy as np

x_data = np.array([[2.0, 3.0], [-1.0, 10.0], [-1.0, -2.0], [5.0, 2.0]])
y_target = np.array([[5.0], [9.0], [-3.0], [7.0]])

w = Tensor(np.random.randn(2, 1)) 
b = Tensor(np.zeros((1,)))

print(f"Starting weights:\n{w.data}")
# Out:
# Starting weights:
# [[ 0.49373019]
#  [-1.73077076]]

# %%
lr = 0.01 # Learning Rate

for step in range(50):

    # Forward Pass
    inputs = Tensor(x_data)
    targets = Tensor(y_target)

    # Model: x @ w + b
    logits = inputs @ w + b

    # Loss function
    # diff = logits - targets
    # loss = (diff**2).mean()
    loss = F.mse_loss(logits, targets)

    # Backward Pass
    w.grad = np.zeros_like(w.data)
    b.grad = np.zeros_like(b.data)

    # Update gradients
    loss.backward()

    # Update data
    w.data -= lr * w.grad
    b.data -= lr * b.grad

    if step % 10 == 0:
        print(f"Step {step}, Loss: {loss.data}")

print(f"\nWeights after training (Target: [1, 1]):\n{w.data}")
print(f"Bias (Tafget: 0):\n{b.data}")
# Out:
# Step 0, Loss: 225.6368590496906
# Step 10, Loss: 0.058985303710339755
# Step 20, Loss: 0.040310941665902024
# Step 30, Loss: 0.03287160732416381
# Step 40, Loss: 0.027032211775346156
#
# Weights after training (Target: [1, 1]):
# [[0.96966974]
#  [0.97830166]]
# Bias (Tafget: 0):
# [0.21071901]
